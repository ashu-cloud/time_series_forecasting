# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install statsmodels --upgrade
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Collecting statsmodels
#   Downloading statsmodels-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 8.9 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.19.5)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# Installing collected packages: statsmodels
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed statsmodels-0.13.1

# %%
import pandas as pd
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/household_power_consumption.txt', delimiter=';')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#          Date      Time  ... Sub_metering_2 Sub_metering_3
# 0  16/12/2006  17:24:00  ...          1.000           17.0
# 1  16/12/2006  17:25:00  ...          1.000           16.0
# 2  16/12/2006  17:26:00  ...          2.000           17.0
# 3  16/12/2006  17:27:00  ...          1.000           17.0
# 4  16/12/2006  17:28:00  ...          1.000           17.0
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
#  6   Sub_metering_1         object
#  7   Sub_metering_2         object
#  8   Sub_metering_3         float64
# dtypes: float64(1), object(8)
# memory usage: 142.5+ MB

# %%
for column in df.columns:
    print("{}: {}".format(column, df[column].isna().sum()))
# Out:
# Date: 0
# Time: 0
# Global_active_power: 0
# Global_reactive_power: 0
# Voltage: 0
# Global_intensity: 0
# Sub_metering_1: 0
# Sub_metering_2: 0
# Sub_metering_3: 25979

# %%
df["Datetime"] = df["Date"] + " " + df["Time"]
df["Datetime"] = pd.to_datetime(df["Datetime"], format='%d/%m/%Y %H:%M:%S')
df = df[["Datetime", "Global_active_power"]]
df['Global_active_power'] = pd.to_numeric(df['Global_active_power'], errors='coerce')
df = df.dropna()

# %%
df.head()
# Out:
#              Datetime  Global_active_power
# 0 2006-12-16 17:24:00                4.216
# 1 2006-12-16 17:25:00                5.360
# 2 2006-12-16 17:26:00                5.374
# 3 2006-12-16 17:27:00                5.388
# 4 2006-12-16 17:28:00                3.666

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2049280 entries, 0 to 2075258
# Data columns (total 2 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Datetime             datetime64[ns]
#  1   Global_active_power  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 46.9 MB

# %%
df.set_index('Datetime', inplace=True)

df = df.resample('H').median()
df.dropna(inplace=True)

df.reset_index(inplace=True)

# %%
df.head()
# Out:
#              Datetime  Global_active_power
# 0 2006-12-16 17:00:00                3.743
# 1 2006-12-16 18:00:00                3.286
# 2 2006-12-16 19:00:00                3.392
# 3 2006-12-16 20:00:00                3.296
# 4 2006-12-16 21:00:00                3.341

# %% [markdown]
# # Autoregressive Model

# %%
train, test = df["Global_active_power"].iloc[:int(0.8*len(df))], df["Global_active_power"].iloc[int(0.8*len(df)):]

# %%
# Baseline RMSE
rmse_0 = np.sqrt(mean_squared_error(test, [np.mean(train) for i in range(len(test))]))
rmse_0
# Out:
# 0.7416156659580303

# %%
# Parameters Grid
lags = np.linspace(10, 1000, 50)
lags = [int(lag) for lag in lags]
rmses = []

# %%
# Grid Search on Parameters (Lags)
for lag in lags:
    print(lag)
    model = AutoReg(train, lags=lag)
    model_fit = model.fit()
    predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=True)
    rmses.append(np.sqrt(mean_squared_error(test, predictions)))
# Out:
# 10
# 30
# 50
# 70
# 90
# 111
# 131
# 151
# 171
# 191
# 212
# 232
# 252
# 272
# 292
# 313
# 333
# 353
# 373
# 393
# 414
# 434
# 454
# 474
# 494
# 515
# 535
# 555
# 575
# 595
# 616
# 636
# 656
# 676
# 696
# 717
# 737
# 757
# 777
# 797
# 818
# 838
# 858
# 878
# 898
# 919
# 939
# 959
# 979
# 1000

# %%
plt.figure(figsize=(16,6))
plt.xlabel("Lag", size=12)
plt.ylabel("Loss", size=12)
plt.plot(lags, rmses)
plt.grid(True)
plt.xlim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
i = np.argmin(rmses)
optimal = lags[i]

# %%
rmses[i]
# Out:
# 0.7236950117140423

# %%
model8 = AutoReg(train, lags=optimal)
model_fit8 = model8.fit()
predictions8 = model_fit8.predict(start=len(train), end=len(train)+len(test)-1)

# %%
plt.figure(figsize=(16, 6))
plt.title("Predictions using AR", size=15)
plt.plot([i for i in range(len(test))], predictions8, label="Predictions")
plt.plot([i for i in range(len(test))], test, linestyle="--", label="Actual")
plt.axhline(np.mean(train), label="Mean", color = "green")
plt.ylabel("Power", size=12)
plt.xlabel("Time Steps", size=12)
plt.xlim(0, 100)
plt.ylim(0, 4)
plt.legend()
plt.grid(True)

# %% [markdown]
# # ARIMA

# %%
plot_acf(df["Global_active_power"], lags=50)

# %%
plot_pacf(df["Global_active_power"], lags=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
train, test = df["Global_active_power"].iloc[:int(0.8*len(df))], df["Global_active_power"].iloc[int(0.8*len(df)):]

# %%
rmse_0 = np.sqrt(mean_squared_error(test, [np.mean(train) for i in range(len(test))]))
rmse_0
# Out:
# 0.7416156659580303

# %%
ps = [1,2,3,4,5]
ds = [0,1]
qs = [0,1,2]
parameters = []
for p in ps:
    for q in qs:
        for d in ds:
            parameters.append((p,d,q))
rmses = []
parameters
# Out:
# [(1, 0, 0),
#  (1, 1, 0),
#  (1, 0, 1),
#  (1, 1, 1),
#  (1, 0, 2),
#  (1, 1, 2),
#  (2, 0, 0),
#  (2, 1, 0),
#  (2, 0, 1),
#  (2, 1, 1),
#  (2, 0, 2),
#  (2, 1, 2),
#  (3, 0, 0),
#  (3, 1, 0),
#  (3, 0, 1),
#  (3, 1, 1),
#  (3, 0, 2),
#  (3, 1, 2),
#  (4, 0, 0),
#  (4, 1, 0),
#  (4, 0, 1),
#  (4, 1, 1),
#  (4, 0, 2),
#  (4, 1, 2),
#  (5, 0, 0),
#  (5, 1, 0),
#  (5, 0, 1),
#  (5, 1, 1),
#  (5, 0, 2),
#  (5, 1, 2)]

# %%
for p,d,q in parameters:
    print(p, d, q)
    model = ARIMA(train, order=(p,d,q))
    model_fit = model.fit()
    predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1)
    rmses.append(np.sqrt(mean_squared_error(test, predictions)))
# Out:
# 1 0 0
# 1 1 0
# 1 0 1
# 1 1 1
# 1 0 2
# 1 1 2
# 2 0 0
# 2 1 0
# 2 0 1
# 2 1 1
# 2 0 2
# 2 1 2
# 3 0 0
# 3 1 0
# 3 0 1
# 3 1 1
# 3 0 2
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# 3 1 2
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# 4 0 0
# 4 1 0
# 4 0 1
# 4 1 1
# 4 0 2
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# 4 1 2
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# 5 0 0
# 5 1 0
# 5 0 1
# 5 1 1
# 5 0 2
# 5 1 2
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
plt.figure(figsize=(16,6))
plt.xlabel("Parameters", size=12)
plt.ylabel("Loss", size=12)
plt.scatter([i for i in range(len(rmses))], rmses)
temp = [str(i) for i in parameters]
# plt.xticks(temp, rotation = 90)
plt.grid(True)
# plt.xlim(0, 1000)

# %%
i = np.argmin(rmses)
optimal = parameters[i]

# %%
optimal
# Out:
# (3, 0, 2)

# %%
model9 = ARIMA(train, order=optimal)
model_fit9 = model9.fit()
predictions9 = model_fit9.predict(start=len(train), end=len(train)+len(test)-1)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
plt.figure(figsize=(16, 6))
plt.title("Predictions using ARIMA", size=15)
plt.plot([i for i in range(len(test))], predictions9, label="Predictions")
plt.plot([i for i in range(len(test))], test, linestyle="--", label="Actual")
plt.axhline(np.mean(train), label="Mean", color = "green")
plt.ylabel("Power", size=12)
plt.xlabel("Time Steps", size=12)
plt.xlim(0, 100)
plt.ylim(0, 4)
plt.legend()
plt.grid(True)

# %%
plt.figure(figsize=(16, 6))
# plt.title("Predictions using AR", size=15)
plt.plot([i for i in range(len(test))], predictions8, label="AR")
plt.plot([i for i in range(len(test))], predictions9, label="ARIMA")
plt.plot([i for i in range(len(test))], test, linestyle="--", label="Actual")
# plt.axhline(np.mean(train), label="Mean", color = "green")
plt.ylabel("Power", size=12)
plt.xlabel("Time Steps", size=12)
plt.xlim(0, 100)
plt.ylim(0, 4)
plt.legend()
plt.grid(True)

# %% [markdown]
# # Simple LSTM Network for Regression

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(np.asarray(df["Global_active_power"]).reshape(-1, 1))

# %%
num_historical_entries = 30
data_input, data_output = [], []
for i in range(len(data)-num_historical_entries-1):
    data_input.append(np.asarray(data[i:(i+num_historical_entries)]))
    data_output.append(data[i + num_historical_entries])

# %%
x_train, y_train = np.asarray(data_input[:int(0.8*len(df))]), np.asarray(data_output[:int(0.8*len(df))])
x_test, y_test = np.asarray(data_input[int(0.8*len(df)):]), np.asarray(data_output[int(0.8*len(df)):])

# %%
np.shape(x_train)
# Out:
# (27334, 30, 1)

# %%
# Reshape according to the requirements of the LSTM model
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

# %%
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20) 

model1 = Sequential()
model1.add(LSTM(200,
               activation="sigmoid",
               input_shape=(x_train.shape[1], x_train.shape[2])))
model1.add(Dropout(0.2))
model1.add(Dense(1))
model1.compile(loss='mean_squared_error',
              optimizer= Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-06))
history1 = model1.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test), verbose=2, callbacks=es, shuffle=False)
# Out:
# Epoch 1/100
# 428/428 - 4s - loss: 0.0629 - val_loss: 0.0117 - 4s/epoch - 10ms/step
# Epoch 2/100
# 428/428 - 3s - loss: 0.0497 - val_loss: 0.0106 - 3s/epoch - 6ms/step
# Epoch 3/100
# 428/428 - 3s - loss: 0.0455 - val_loss: 0.0100 - 3s/epoch - 6ms/step
# Epoch 4/100
# 428/428 - 3s - loss: 0.0405 - val_loss: 0.0100 - 3s/epoch - 6ms/step
# Epoch 5/100
# 428/428 - 3s - loss: 0.0366 - val_loss: 0.0094 - 3s/epoch - 6ms/step
# Epoch 6/100
# 428/428 - 3s - loss: 0.0326 - val_loss: 0.0093 - 3s/epoch - 6ms/step
# Epoch 7/100
# 428/428 - 3s - loss: 0.0294 - val_loss: 0.0090 - 3s/epoch - 6ms/step
# Epoch 8/100
# 428/428 - 3s - loss: 0.0269 - val_loss: 0.0093 - 3s/epoch - 6ms/step
# Epoch 9/100
# 428/428 - 3s - loss: 0.0245 - val_loss: 0.0092 - 3s/epoch - 7ms/step
# Epoch 10/100
# 428/428 - 3s - loss: 0.0222 - val_loss: 0.0090 - 3s/epoch - 6ms/step
# Epoch 11/100
# 428/428 - 3s - loss: 0.0204 - val_loss: 0.0091 - 3s/epoch - 7ms/step
# Epoch 12/100
# 428/428 - 3s - loss: 0.0193 - val_loss: 0.0091 - 3s/epoch - 6ms/step
# Epoch 13/100
# 428/428 - 3s - loss: 0.0181 - val_loss: 0.0090 - 3s/epoch - 6ms/step
# Epoch 14/100
# 428/428 - 3s - loss: 0.0168 - val_loss: 0.0089 - 3s/epoch - 7ms/step
# Epoch 15/100
# 428/428 - 3s - loss: 0.0162 - val_loss: 0.0093 - 3s/epoch - 7ms/step
# Epoch 16/100
# 428/428 - 3s - loss: 0.0155 - val_loss: 0.0091 - 3s/epoch - 7ms/step
# Epoch 17/100
# 428/428 - 3s - loss: 0.0147 - val_loss: 0.0092 - 3s/epoch - 6ms/step
# Epoch 18/100
# 428/428 - 3s - loss: 0.0145 - val_loss: 0.0091 - 3s/epoch - 6ms/step
# Epoch 19/100
# 428/428 - 3s - loss: 0.0139 - val_loss: 0.0090 - 3s/epoch - 7ms/step
# Epoch 20/100
# 428/428 - 3s - loss: 0.0137 - val_loss: 0.0090 - 3s/epoch - 7ms/step
# Epoch 21/100
# 428/428 - 3s - loss: 0.0134 - val_loss: 0.0089 - 3s/epoch - 7ms/step
# Epoch 22/100
# 428/428 - 3s - loss: 0.0131 - val_loss: 0.0090 - 3s/epoch - 7ms/step
# Epoch 23/100
# 428/428 - 3s - loss: 0.0129 - val_loss: 0.0089 - 3s/epoch - 7ms/step
# Epoch 24/100
# 428/428 - 3s - loss: 0.0127 - val_loss: 0.0091 - 3s/epoch - 6ms/step
# Epoch 25/100
# 428/428 - 3s - loss: 0.0126 - val_loss: 0.0090 - 3s/epoch - 6ms/step
# Epoch 26/100
# 428/428 - 3s - loss: 0.0125 - val_loss: 0.0089 - 3s/epoch - 7ms/step
# Epoch 27/100
# 428/428 - 3s - loss: 0.0123 - val_loss: 0.0092 - 3s/epoch - 7ms/step
# Epoch 28/100
# 428/428 - 3s - loss: 0.0122 - val_loss: 0.0088 - 3s/epoch - 7ms/step
# Epoch 29/100
# 428/428 - 3s - loss: 0.0121 - val_loss: 0.0087 - 3s/epoch - 7ms/step
# Epoch 30/100
# 428/428 - 3s - loss: 0.0120 - val_loss: 0.0087 - 3s/epoch - 7ms/step
# Epoch 31/100
# 428/428 - 3s - loss: 0.0120 - val_loss: 0.0088 - 3s/epoch - 7ms/step
# Epoch 32/100
# 428/428 - 3s - loss: 0.0119 - val_loss: 0.0087 - 3s/epoch - 7ms/step
# Epoch 33/100
# 428/428 - 3s - loss: 0.0120 - val_loss: 0.0086 - 3s/epoch - 7ms/step
# Epoch 34/100
# 428/428 - 3s - loss: 0.0118 - val_loss: 0.0086 - 3s/epoch - 7ms/step
# Epoch 35/100
# 428/428 - 3s - loss: 0.0117 - val_loss: 0.0086 - 3s/epoch - 7ms/step
# Epoch 36/100
# 428/428 - 3s - loss: 0.0117 - val_loss: 0.0086 - 3s/epoch - 7ms/step
# Epoch 37/100
# 428/428 - 3s - loss: 0.0116 - val_loss: 0.0084 - 3s/epoch - 7ms/step
# Epoch 38/100
# 428/428 - 3s - loss: 0.0115 - val_loss: 0.0087 - 3s/epoch - 7ms/step
# Epoch 39/100
# 428/428 - 3s - loss: 0.0115 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 40/100
# 428/428 - 3s - loss: 0.0115 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 41/100
# 428/428 - 3s - loss: 0.0114 - val_loss: 0.0085 - 3s/epoch - 6ms/step
# Epoch 42/100
# 428/428 - 3s - loss: 0.0114 - val_loss: 0.0086 - 3s/epoch - 6ms/step
# Epoch 43/100
# 428/428 - 3s - loss: 0.0113 - val_loss: 0.0084 - 3s/epoch - 6ms/step
# Epoch 44/100
# 428/428 - 3s - loss: 0.0113 - val_loss: 0.0084 - 3s/epoch - 6ms/step
# Epoch 45/100
# 428/428 - 3s - loss: 0.0113 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 46/100
# 428/428 - 3s - loss: 0.0113 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 47/100
# 428/428 - 3s - loss: 0.0112 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 48/100
# 428/428 - 3s - loss: 0.0112 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 49/100
# 428/428 - 3s - loss: 0.0112 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 50/100
# 428/428 - 3s - loss: 0.0112 - val_loss: 0.0084 - 3s/epoch - 6ms/step
# Epoch 51/100
# 428/428 - 3s - loss: 0.0111 - val_loss: 0.0086 - 3s/epoch - 6ms/step
# Epoch 52/100
# 428/428 - 3s - loss: 0.0111 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 53/100
# 428/428 - 3s - loss: 0.0111 - val_loss: 0.0085 - 3s/epoch - 6ms/step
# Epoch 54/100
# 428/428 - 3s - loss: 0.0111 - val_loss: 0.0084 - 3s/epoch - 7ms/step
# Epoch 55/100
# 428/428 - 3s - loss: 0.0110 - val_loss: 0.0084 - 3s/epoch - 7ms/step
# Epoch 56/100
# 428/428 - 3s - loss: 0.0111 - val_loss: 0.0084 - 3s/epoch - 7ms/step
# Epoch 57/100
# 428/428 - 3s - loss: 0.0110 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 58/100
# 428/428 - 3s - loss: 0.0110 - val_loss: 0.0084 - 3s/epoch - 7ms/step
# Epoch 59/100
# 428/428 - 3s - loss: 0.0110 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 60/100
# 428/428 - 3s - loss: 0.0110 - val_loss: 0.0083 - 3s/epoch - 6ms/step
# Epoch 61/100
# 428/428 - 3s - loss: 0.0110 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 62/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0082 - 3s/epoch - 6ms/step
# Epoch 63/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0084 - 3s/epoch - 7ms/step
# Epoch 64/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 65/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0082 - 3s/epoch - 7ms/step
# Epoch 66/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0084 - 3s/epoch - 7ms/step
# Epoch 67/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 68/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 69/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0084 - 3s/epoch - 8ms/step
# Epoch 70/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0083 - 3s/epoch - 8ms/step
# Epoch 71/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0084 - 3s/epoch - 7ms/step
# Epoch 72/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 73/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 74/100
# 428/428 - 3s - loss: 0.0109 - val_loss: 0.0083 - 3s/epoch - 8ms/step
# Epoch 75/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0083 - 3s/epoch - 8ms/step
# Epoch 76/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 77/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 78/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0082 - 3s/epoch - 7ms/step
# Epoch 79/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0082 - 3s/epoch - 7ms/step
# Epoch 80/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0082 - 3s/epoch - 7ms/step
# Epoch 81/100
# 428/428 - 4s - loss: 0.0108 - val_loss: 0.0084 - 4s/epoch - 9ms/step
# Epoch 82/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0083 - 3s/epoch - 8ms/step
# Epoch 83/100
# 428/428 - 3s - loss: 0.0108 - val_loss: 0.0083 - 3s/epoch - 7ms/step
# Epoch 84/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0084 - 3s/epoch - 8ms/step
# Epoch 85/100
# 428/428 - 4s - loss: 0.0107 - val_loss: 0.0082 - 4s/epoch - 9ms/step
# Epoch 86/100
# 428/428 - 4s - loss: 0.0107 - val_loss: 0.0084 - 4s/epoch - 9ms/step
# Epoch 87/100
# 428/428 - 4s - loss: 0.0107 - val_loss: 0.0084 - 4s/epoch - 8ms/step
# Epoch 88/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0083 - 3s/epoch - 8ms/step
# Epoch 89/100
# 428/428 - 4s - loss: 0.0106 - val_loss: 0.0083 - 4s/epoch - 8ms/step
# Epoch 90/100
# 428/428 - 4s - loss: 0.0107 - val_loss: 0.0083 - 4s/epoch - 9ms/step
# Epoch 91/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0082 - 3s/epoch - 8ms/step
# Epoch 92/100
# 428/428 - 4s - loss: 0.0107 - val_loss: 0.0083 - 4s/epoch - 9ms/step
# Epoch 93/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0083 - 3s/epoch - 8ms/step
# Epoch 94/100
# 428/428 - 4s - loss: 0.0107 - val_loss: 0.0083 - 4s/epoch - 9ms/step
# Epoch 95/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0082 - 3s/epoch - 8ms/step
# Epoch 96/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0083 - 3s/epoch - 8ms/step
# Epoch 97/100
# 428/428 - 3s - loss: 0.0107 - val_loss: 0.0082 - 3s/epoch - 8ms/step
# Epoch 98/100
# 428/428 - 3s - loss: 0.0106 - val_loss: 0.0082 - 3s/epoch - 8ms/step
# Epoch 99/100
# 428/428 - 3s - loss: 0.0106 - val_loss: 0.0082 - 3s/epoch - 8ms/step
# Epoch 100/100
# 428/428 - 3s - loss: 0.0106 - val_loss: 0.0082 - 3s/epoch - 7ms/step
# Epoch 00100: early stopping

# %%
test_predicted1 = model1.predict(x_test)

# %%
mean_squared_error(y_test, test_predicted1)
# Out:
# 0.008242351931975

# %%
plt.figure(figsize=(16, 6))
plt.title("Prediction using Simple LSTM Model", size=15)
plt.plot(y_test, label = "Actual")
plt.plot(test_predicted1, label = "Predicted")
plt.xlim(0, 200)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %%
# Baseline RMSE
rmse_0 = np.sqrt(mean_squared_error(y_test, [np.mean(y_train) for i in range(len(y_test))]))
rmse_0
# Out:
# 0.11247137264631518

# %% [markdown]
# # Stacked LSTM Network for Regression

# %%
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10) 

model2 = Sequential()
model2.add(LSTM(200,
               return_sequences=True,
               activation="sigmoid",
               input_shape=(x_train.shape[1], x_train.shape[2])))
model2.add(LSTM(200,
               activation="sigmoid"))
model2.add(Dropout(0.2))
model2.add(Dense(1))
model2.compile(loss='mean_squared_error',
              optimizer= Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-06))
history2 = model2.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test), verbose=2, callbacks=es, shuffle=False)
# Out:
# Epoch 1/100
# 428/428 - 9s - loss: 0.0515 - val_loss: 0.0156 - 9s/epoch - 22ms/step
# Epoch 2/100
# 428/428 - 7s - loss: 0.0378 - val_loss: 0.0159 - 7s/epoch - 15ms/step
# Epoch 3/100
# 428/428 - 6s - loss: 0.0305 - val_loss: 0.0163 - 6s/epoch - 15ms/step
# Epoch 4/100
# 428/428 - 6s - loss: 0.0255 - val_loss: 0.0155 - 6s/epoch - 15ms/step
# Epoch 5/100
# 428/428 - 7s - loss: 0.0221 - val_loss: 0.0144 - 7s/epoch - 16ms/step
# Epoch 6/100
# 428/428 - 6s - loss: 0.0199 - val_loss: 0.0132 - 6s/epoch - 15ms/step
# Epoch 7/100
# 428/428 - 6s - loss: 0.0184 - val_loss: 0.0124 - 6s/epoch - 15ms/step
# Epoch 8/100
# 428/428 - 6s - loss: 0.0171 - val_loss: 0.0120 - 6s/epoch - 14ms/step
# Epoch 9/100
# 428/428 - 6s - loss: 0.0159 - val_loss: 0.0112 - 6s/epoch - 14ms/step
# Epoch 10/100
# 428/428 - 6s - loss: 0.0152 - val_loss: 0.0109 - 6s/epoch - 15ms/step
# Epoch 11/100
# 428/428 - 6s - loss: 0.0145 - val_loss: 0.0105 - 6s/epoch - 15ms/step
# Epoch 12/100
# 428/428 - 6s - loss: 0.0139 - val_loss: 0.0100 - 6s/epoch - 14ms/step
# Epoch 13/100
# 428/428 - 6s - loss: 0.0135 - val_loss: 0.0099 - 6s/epoch - 14ms/step
# Epoch 14/100
# 428/428 - 6s - loss: 0.0132 - val_loss: 0.0095 - 6s/epoch - 14ms/step
# Epoch 15/100
# 428/428 - 6s - loss: 0.0128 - val_loss: 0.0095 - 6s/epoch - 13ms/step
# Epoch 16/100
# 428/428 - 6s - loss: 0.0125 - val_loss: 0.0094 - 6s/epoch - 14ms/step
# Epoch 17/100
# 428/428 - 6s - loss: 0.0124 - val_loss: 0.0093 - 6s/epoch - 14ms/step
# Epoch 18/100
# 428/428 - 6s - loss: 0.0122 - val_loss: 0.0091 - 6s/epoch - 14ms/step
# Epoch 19/100
# 428/428 - 6s - loss: 0.0120 - val_loss: 0.0092 - 6s/epoch - 14ms/step
# Epoch 20/100
# 428/428 - 6s - loss: 0.0119 - val_loss: 0.0091 - 6s/epoch - 15ms/step
# Epoch 21/100
# 428/428 - 6s - loss: 0.0117 - val_loss: 0.0088 - 6s/epoch - 15ms/step
# Epoch 22/100
# 428/428 - 6s - loss: 0.0116 - val_loss: 0.0087 - 6s/epoch - 15ms/step
# Epoch 23/100
# 428/428 - 6s - loss: 0.0115 - val_loss: 0.0086 - 6s/epoch - 14ms/step
# Epoch 24/100
# 428/428 - 6s - loss: 0.0114 - val_loss: 0.0088 - 6s/epoch - 14ms/step
# Epoch 25/100
# 428/428 - 6s - loss: 0.0113 - val_loss: 0.0086 - 6s/epoch - 13ms/step
# Epoch 26/100
# 428/428 - 5s - loss: 0.0112 - val_loss: 0.0085 - 5s/epoch - 13ms/step
# Epoch 27/100
# 428/428 - 6s - loss: 0.0111 - val_loss: 0.0085 - 6s/epoch - 13ms/step
# Epoch 28/100
# 428/428 - 6s - loss: 0.0111 - val_loss: 0.0084 - 6s/epoch - 13ms/step
# Epoch 29/100
# 428/428 - 6s - loss: 0.0110 - val_loss: 0.0084 - 6s/epoch - 13ms/step
# Epoch 30/100
# 428/428 - 6s - loss: 0.0109 - val_loss: 0.0084 - 6s/epoch - 13ms/step
# Epoch 31/100
# 428/428 - 5s - loss: 0.0109 - val_loss: 0.0085 - 5s/epoch - 13ms/step
# Epoch 32/100
# 428/428 - 6s - loss: 0.0108 - val_loss: 0.0083 - 6s/epoch - 14ms/step
# Epoch 33/100
# 428/428 - 6s - loss: 0.0108 - val_loss: 0.0084 - 6s/epoch - 13ms/step
# Epoch 34/100
# 428/428 - 5s - loss: 0.0108 - val_loss: 0.0083 - 5s/epoch - 12ms/step
# Epoch 35/100
# 428/428 - 6s - loss: 0.0107 - val_loss: 0.0084 - 6s/epoch - 13ms/step
# Epoch 36/100
# 428/428 - 6s - loss: 0.0107 - val_loss: 0.0082 - 6s/epoch - 13ms/step
# Epoch 37/100
# 428/428 - 6s - loss: 0.0107 - val_loss: 0.0082 - 6s/epoch - 13ms/step
# Epoch 38/100
# 428/428 - 5s - loss: 0.0107 - val_loss: 0.0083 - 5s/epoch - 12ms/step
# Epoch 39/100
# 428/428 - 5s - loss: 0.0106 - val_loss: 0.0083 - 5s/epoch - 13ms/step
# Epoch 40/100
# 428/428 - 5s - loss: 0.0106 - val_loss: 0.0082 - 5s/epoch - 13ms/step
# Epoch 41/100
# 428/428 - 6s - loss: 0.0106 - val_loss: 0.0082 - 6s/epoch - 13ms/step
# Epoch 42/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0082 - 5s/epoch - 13ms/step
# Epoch 43/100
# 428/428 - 5s - loss: 0.0106 - val_loss: 0.0082 - 5s/epoch - 13ms/step
# Epoch 44/100
# 428/428 - 5s - loss: 0.0106 - val_loss: 0.0082 - 5s/epoch - 13ms/step
# Epoch 45/100
# 428/428 - 6s - loss: 0.0105 - val_loss: 0.0082 - 6s/epoch - 13ms/step
# Epoch 46/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0082 - 5s/epoch - 13ms/step
# Epoch 47/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0082 - 5s/epoch - 13ms/step
# Epoch 48/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0081 - 5s/epoch - 13ms/step
# Epoch 49/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0081 - 5s/epoch - 13ms/step
# Epoch 50/100
# 428/428 - 5s - loss: 0.0104 - val_loss: 0.0081 - 5s/epoch - 13ms/step
# Epoch 51/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0082 - 5s/epoch - 13ms/step
# Epoch 52/100
# 428/428 - 6s - loss: 0.0105 - val_loss: 0.0081 - 6s/epoch - 15ms/step
# Epoch 53/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0081 - 6s/epoch - 15ms/step
# Epoch 54/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0081 - 6s/epoch - 14ms/step
# Epoch 55/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0081 - 6s/epoch - 13ms/step
# Epoch 56/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0081 - 6s/epoch - 14ms/step
# Epoch 57/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0081 - 6s/epoch - 14ms/step
# Epoch 58/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0080 - 6s/epoch - 14ms/step
# Epoch 59/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0080 - 6s/epoch - 14ms/step
# Epoch 60/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0081 - 6s/epoch - 14ms/step
# Epoch 61/100
# 428/428 - 6s - loss: 0.0104 - val_loss: 0.0080 - 6s/epoch - 14ms/step
# Epoch 62/100
# 428/428 - 7s - loss: 0.0104 - val_loss: 0.0080 - 7s/epoch - 15ms/step
# Epoch 63/100
# 428/428 - 7s - loss: 0.0104 - val_loss: 0.0081 - 7s/epoch - 16ms/step
# Epoch 64/100
# 428/428 - 7s - loss: 0.0104 - val_loss: 0.0081 - 7s/epoch - 16ms/step
# Epoch 65/100
# 428/428 - 7s - loss: 0.0104 - val_loss: 0.0081 - 7s/epoch - 16ms/step
# Epoch 66/100
# 428/428 - 7s - loss: 0.0104 - val_loss: 0.0080 - 7s/epoch - 15ms/step
# Epoch 67/100
# 428/428 - 6s - loss: 0.0103 - val_loss: 0.0080 - 6s/epoch - 15ms/step
# Epoch 68/100
# 428/428 - 7s - loss: 0.0103 - val_loss: 0.0080 - 7s/epoch - 15ms/step
# Epoch 69/100
# 428/428 - 6s - loss: 0.0103 - val_loss: 0.0080 - 6s/epoch - 15ms/step
# Epoch 70/100
# 428/428 - 6s - loss: 0.0103 - val_loss: 0.0080 - 6s/epoch - 15ms/step
# Epoch 71/100
# 428/428 - 6s - loss: 0.0103 - val_loss: 0.0080 - 6s/epoch - 15ms/step
# Epoch 72/100
# 428/428 - 7s - loss: 0.0103 - val_loss: 0.0081 - 7s/epoch - 15ms/step
# Epoch 73/100
# 428/428 - 6s - loss: 0.0103 - val_loss: 0.0079 - 6s/epoch - 15ms/step
# Epoch 74/100
# 428/428 - 6s - loss: 0.0103 - val_loss: 0.0080 - 6s/epoch - 15ms/step
# Epoch 75/100
# 428/428 - 7s - loss: 0.0103 - val_loss: 0.0080 - 7s/epoch - 16ms/step
# Epoch 76/100
# 428/428 - 7s - loss: 0.0103 - val_loss: 0.0080 - 7s/epoch - 17ms/step
# Epoch 77/100
# 428/428 - 7s - loss: 0.0103 - val_loss: 0.0080 - 7s/epoch - 16ms/step
# Epoch 78/100
# 428/428 - 7s - loss: 0.0103 - val_loss: 0.0080 - 7s/epoch - 17ms/step
# Epoch 79/100
# 428/428 - 8s - loss: 0.0103 - val_loss: 0.0080 - 8s/epoch - 18ms/step
# Epoch 80/100
# 428/428 - 8s - loss: 0.0103 - val_loss: 0.0080 - 8s/epoch - 18ms/step
# Epoch 81/100
# 428/428 - 7s - loss: 0.0103 - val_loss: 0.0080 - 7s/epoch - 17ms/step
# Epoch 82/100
# 428/428 - 8s - loss: 0.0103 - val_loss: 0.0080 - 8s/epoch - 18ms/step
# Epoch 83/100
# 428/428 - 7s - loss: 0.0103 - val_loss: 0.0080 - 7s/epoch - 17ms/step
# Epoch 00083: early stopping

# %%
test_predicted2 = model2.predict(x_test)
test_predicted2 = np.squeeze(test_predicted2)
mean_squared_error(y_test, test_predicted2)
# Out:
# 0.008022355135522212

# %%
plt.figure(figsize=(16, 6))
plt.title("Prediction using Stacked LSTM Model", size=15)
plt.plot(y_test, label="Actual")
plt.plot(test_predicted2, label="Predicted")
plt.xlim(0, 200)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %% [markdown]
# # Bidirectional LSTM Network for Regression

# %%
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Dense, Bidirectional
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10) 

model3 = Sequential()
model3.add(Bidirectional(LSTM(200,
               activation="sigmoid",
               input_shape=(x_train.shape[1], x_train.shape[2]))))
model3.add(Dropout(0.2))
model3.add(Dense(1))
model3.compile(loss='mean_squared_error',
              optimizer= Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-06))
history3 = model3.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test), verbose=2, callbacks=es, shuffle=False)
# Out:
# Epoch 1/100
# 428/428 - 8s - loss: 0.0673 - val_loss: 0.0111 - 8s/epoch - 19ms/step
# Epoch 2/100
# 428/428 - 5s - loss: 0.0508 - val_loss: 0.0105 - 5s/epoch - 12ms/step
# Epoch 3/100
# 428/428 - 5s - loss: 0.0465 - val_loss: 0.0100 - 5s/epoch - 12ms/step
# Epoch 4/100
# 428/428 - 5s - loss: 0.0424 - val_loss: 0.0107 - 5s/epoch - 12ms/step
# Epoch 5/100
# 428/428 - 5s - loss: 0.0384 - val_loss: 0.0091 - 5s/epoch - 11ms/step
# Epoch 6/100
# 428/428 - 5s - loss: 0.0347 - val_loss: 0.0094 - 5s/epoch - 13ms/step
# Epoch 7/100
# 428/428 - 5s - loss: 0.0310 - val_loss: 0.0095 - 5s/epoch - 12ms/step
# Epoch 8/100
# 428/428 - 5s - loss: 0.0283 - val_loss: 0.0089 - 5s/epoch - 12ms/step
# Epoch 9/100
# 428/428 - 5s - loss: 0.0254 - val_loss: 0.0092 - 5s/epoch - 11ms/step
# Epoch 10/100
# 428/428 - 5s - loss: 0.0231 - val_loss: 0.0100 - 5s/epoch - 13ms/step
# Epoch 11/100
# 428/428 - 5s - loss: 0.0212 - val_loss: 0.0093 - 5s/epoch - 12ms/step
# Epoch 12/100
# 428/428 - 5s - loss: 0.0196 - val_loss: 0.0098 - 5s/epoch - 11ms/step
# Epoch 13/100
# 428/428 - 5s - loss: 0.0178 - val_loss: 0.0087 - 5s/epoch - 12ms/step
# Epoch 14/100
# 428/428 - 5s - loss: 0.0170 - val_loss: 0.0098 - 5s/epoch - 12ms/step
# Epoch 15/100
# 428/428 - 5s - loss: 0.0161 - val_loss: 0.0091 - 5s/epoch - 12ms/step
# Epoch 16/100
# 428/428 - 5s - loss: 0.0153 - val_loss: 0.0092 - 5s/epoch - 12ms/step
# Epoch 17/100
# 428/428 - 5s - loss: 0.0146 - val_loss: 0.0088 - 5s/epoch - 12ms/step
# Epoch 18/100
# 428/428 - 5s - loss: 0.0141 - val_loss: 0.0094 - 5s/epoch - 12ms/step
# Epoch 19/100
# 428/428 - 5s - loss: 0.0138 - val_loss: 0.0093 - 5s/epoch - 12ms/step
# Epoch 20/100
# 428/428 - 5s - loss: 0.0133 - val_loss: 0.0092 - 5s/epoch - 12ms/step
# Epoch 21/100
# 428/428 - 5s - loss: 0.0132 - val_loss: 0.0094 - 5s/epoch - 12ms/step
# Epoch 22/100
# 428/428 - 5s - loss: 0.0127 - val_loss: 0.0092 - 5s/epoch - 11ms/step
# Epoch 23/100
# 428/428 - 5s - loss: 0.0127 - val_loss: 0.0089 - 5s/epoch - 12ms/step
# Epoch 00023: early stopping

# %%
test_predicted3 = model3.predict(x_test)
test_predicted3 = np.squeeze(test_predicted3)
mean_squared_error(y_test, test_predicted3)
# Out:
# 0.008881433768899176

# %%
plt.figure(figsize=(16, 6))
plt.title("Prediction using Bidirectional LSTM Models", size=15)
plt.plot(y_test, label="Actual")
plt.plot(test_predicted3, label="Predicted")
plt.xlim(0, 200)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %% [markdown]
# # Simple Gated Recurrent Units

# %%
from keras.models import Sequential
from keras.layers import Dropout, GRU
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10) 

model4 = Sequential()
model4.add(GRU(200,
               activation="sigmoid",
               input_shape=(x_train.shape[1], x_train.shape[2])))
model4.add(Dropout(0.2))
model4.add(Dense(1))
model4.compile(loss='mean_squared_error',
              optimizer= Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-06))
history4 = model4.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test), verbose=2, callbacks=es, shuffle=False)
# Out:
# Epoch 1/100
# 428/428 - 6s - loss: 0.0517 - val_loss: 0.0105 - 6s/epoch - 14ms/step
# Epoch 2/100
# 428/428 - 3s - loss: 0.0422 - val_loss: 0.0102 - 3s/epoch - 7ms/step
# Epoch 3/100
# 428/428 - 3s - loss: 0.0369 - val_loss: 0.0091 - 3s/epoch - 7ms/step
# Epoch 4/100
# 428/428 - 3s - loss: 0.0328 - val_loss: 0.0090 - 3s/epoch - 7ms/step
# Epoch 5/100
# 428/428 - 3s - loss: 0.0290 - val_loss: 0.0090 - 3s/epoch - 7ms/step
# Epoch 6/100
# 428/428 - 3s - loss: 0.0265 - val_loss: 0.0087 - 3s/epoch - 6ms/step
# Epoch 7/100
# 428/428 - 3s - loss: 0.0234 - val_loss: 0.0086 - 3s/epoch - 6ms/step
# Epoch 8/100
# 428/428 - 3s - loss: 0.0217 - val_loss: 0.0090 - 3s/epoch - 6ms/step
# Epoch 9/100
# 428/428 - 3s - loss: 0.0198 - val_loss: 0.0083 - 3s/epoch - 6ms/step
# Epoch 10/100
# 428/428 - 3s - loss: 0.0183 - val_loss: 0.0086 - 3s/epoch - 6ms/step
# Epoch 11/100
# 428/428 - 3s - loss: 0.0171 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 12/100
# 428/428 - 3s - loss: 0.0162 - val_loss: 0.0086 - 3s/epoch - 7ms/step
# Epoch 13/100
# 428/428 - 3s - loss: 0.0153 - val_loss: 0.0085 - 3s/epoch - 7ms/step
# Epoch 14/100
# 428/428 - 3s - loss: 0.0146 - val_loss: 0.0084 - 3s/epoch - 8ms/step
# Epoch 15/100
# 428/428 - 3s - loss: 0.0141 - val_loss: 0.0088 - 3s/epoch - 8ms/step
# Epoch 16/100
# 428/428 - 3s - loss: 0.0138 - val_loss: 0.0086 - 3s/epoch - 7ms/step
# Epoch 17/100
# 428/428 - 3s - loss: 0.0133 - val_loss: 0.0086 - 3s/epoch - 8ms/step
# Epoch 18/100
# 428/428 - 3s - loss: 0.0130 - val_loss: 0.0085 - 3s/epoch - 8ms/step
# Epoch 19/100
# 428/428 - 3s - loss: 0.0129 - val_loss: 0.0087 - 3s/epoch - 7ms/step
# Epoch 00019: early stopping

# %%
test_predicted4 = model4.predict(x_test)
test_predicted4 = np.squeeze(test_predicted4)
mean_squared_error(y_test, test_predicted4)
# Out:
# 0.008688166872564778

# %%
plt.figure(figsize=(16, 6))
plt.title("Prediction using Gated Recurrent Units", size=15)
plt.plot(y_test, label="Actual")
plt.plot(test_predicted4, label="Predicted")
plt.xlim(0, 200)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %% [markdown]
# # Stacked Gated Recurrent Unit

# %%
from keras.models import Sequential
from keras.layers import Dropout, GRU
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10) 

model5 = Sequential()
model5.add(GRU(200,
               return_sequences=True,
               activation="sigmoid",
               input_shape=(x_train.shape[1], x_train.shape[2])))
model5.add(GRU(200,
               activation="sigmoid",
               input_shape=(x_train.shape[1], x_train.shape[2])))
model5.add(Dropout(0.2))
model5.add(Dense(1))
model5.compile(loss='mean_squared_error',
              optimizer= Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-06))
history5 = model5.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test), verbose=2, callbacks=es, shuffle=False)
# Out:
# Epoch 1/100
# 428/428 - 10s - loss: 0.0475 - val_loss: 0.0154 - 10s/epoch - 23ms/step
# Epoch 2/100
# 428/428 - 6s - loss: 0.0329 - val_loss: 0.0165 - 6s/epoch - 14ms/step
# Epoch 3/100
# 428/428 - 6s - loss: 0.0258 - val_loss: 0.0149 - 6s/epoch - 14ms/step
# Epoch 4/100
# 428/428 - 5s - loss: 0.0212 - val_loss: 0.0134 - 5s/epoch - 13ms/step
# Epoch 5/100
# 428/428 - 6s - loss: 0.0182 - val_loss: 0.0125 - 6s/epoch - 14ms/step
# Epoch 6/100
# 428/428 - 6s - loss: 0.0163 - val_loss: 0.0111 - 6s/epoch - 13ms/step
# Epoch 7/100
# 428/428 - 5s - loss: 0.0150 - val_loss: 0.0104 - 5s/epoch - 13ms/step
# Epoch 8/100
# 428/428 - 6s - loss: 0.0141 - val_loss: 0.0103 - 6s/epoch - 13ms/step
# Epoch 9/100
# 428/428 - 5s - loss: 0.0134 - val_loss: 0.0098 - 5s/epoch - 12ms/step
# Epoch 10/100
# 428/428 - 5s - loss: 0.0129 - val_loss: 0.0096 - 5s/epoch - 13ms/step
# Epoch 11/100
# 428/428 - 5s - loss: 0.0126 - val_loss: 0.0092 - 5s/epoch - 13ms/step
# Epoch 12/100
# 428/428 - 5s - loss: 0.0123 - val_loss: 0.0092 - 5s/epoch - 12ms/step
# Epoch 13/100
# 428/428 - 6s - loss: 0.0120 - val_loss: 0.0090 - 6s/epoch - 13ms/step
# Epoch 14/100
# 428/428 - 5s - loss: 0.0118 - val_loss: 0.0089 - 5s/epoch - 13ms/step
# Epoch 15/100
# 428/428 - 5s - loss: 0.0117 - val_loss: 0.0089 - 5s/epoch - 13ms/step
# Epoch 16/100
# 428/428 - 6s - loss: 0.0114 - val_loss: 0.0088 - 6s/epoch - 13ms/step
# Epoch 17/100
# 428/428 - 5s - loss: 0.0113 - val_loss: 0.0087 - 5s/epoch - 13ms/step
# Epoch 18/100
# 428/428 - 5s - loss: 0.0111 - val_loss: 0.0086 - 5s/epoch - 12ms/step
# Epoch 19/100
# 428/428 - 6s - loss: 0.0111 - val_loss: 0.0086 - 6s/epoch - 13ms/step
# Epoch 20/100
# 428/428 - 5s - loss: 0.0110 - val_loss: 0.0087 - 5s/epoch - 12ms/step
# Epoch 21/100
# 428/428 - 5s - loss: 0.0109 - val_loss: 0.0087 - 5s/epoch - 12ms/step
# Epoch 22/100
# 428/428 - 5s - loss: 0.0109 - val_loss: 0.0085 - 5s/epoch - 13ms/step
# Epoch 23/100
# 428/428 - 6s - loss: 0.0108 - val_loss: 0.0087 - 6s/epoch - 13ms/step
# Epoch 24/100
# 428/428 - 5s - loss: 0.0108 - val_loss: 0.0083 - 5s/epoch - 13ms/step
# Epoch 25/100
# 428/428 - 6s - loss: 0.0107 - val_loss: 0.0085 - 6s/epoch - 13ms/step
# Epoch 26/100
# 428/428 - 6s - loss: 0.0107 - val_loss: 0.0085 - 6s/epoch - 14ms/step
# Epoch 27/100
# 428/428 - 6s - loss: 0.0107 - val_loss: 0.0084 - 6s/epoch - 14ms/step
# Epoch 28/100
# 428/428 - 6s - loss: 0.0106 - val_loss: 0.0085 - 6s/epoch - 14ms/step
# Epoch 29/100
# 428/428 - 6s - loss: 0.0106 - val_loss: 0.0083 - 6s/epoch - 13ms/step
# Epoch 30/100
# 428/428 - 6s - loss: 0.0106 - val_loss: 0.0084 - 6s/epoch - 13ms/step
# Epoch 31/100
# 428/428 - 6s - loss: 0.0105 - val_loss: 0.0083 - 6s/epoch - 14ms/step
# Epoch 32/100
# 428/428 - 6s - loss: 0.0105 - val_loss: 0.0084 - 6s/epoch - 13ms/step
# Epoch 33/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0083 - 5s/epoch - 13ms/step
# Epoch 34/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0082 - 5s/epoch - 12ms/step
# Epoch 35/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0082 - 5s/epoch - 12ms/step
# Epoch 36/100
# 428/428 - 6s - loss: 0.0105 - val_loss: 0.0082 - 6s/epoch - 13ms/step
# Epoch 37/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0081 - 5s/epoch - 12ms/step
# Epoch 38/100
# 428/428 - 5s - loss: 0.0105 - val_loss: 0.0082 - 5s/epoch - 12ms/step
# Epoch 39/100
# 428/428 - 5s - loss: 0.0104 - val_loss: 0.0082 - 5s/epoch - 13ms/step
# Epoch 40/100
# 428/428 - 5s - loss: 0.0104 - val_loss: 0.0081 - 5s/epoch - 12ms/step
# Epoch 41/100
# 428/428 - 5s - loss: 0.0104 - val_loss: 0.0082 - 5s/epoch - 12ms/step
# Epoch 42/100
# 428/428 - 5s - loss: 0.0103 - val_loss: 0.0081 - 5s/epoch - 11ms/step
# Epoch 43/100
# 428/428 - 5s - loss: 0.0104 - val_loss: 0.0082 - 5s/epoch - 12ms/step
# Epoch 44/100
# 428/428 - 5s - loss: 0.0103 - val_loss: 0.0082 - 5s/epoch - 11ms/step
# Epoch 45/100
# 428/428 - 5s - loss: 0.0104 - val_loss: 0.0081 - 5s/epoch - 11ms/step
# Epoch 46/100
# 428/428 - 5s - loss: 0.0103 - val_loss: 0.0082 - 5s/epoch - 11ms/step
# Epoch 47/100
# 428/428 - 5s - loss: 0.0103 - val_loss: 0.0082 - 5s/epoch - 12ms/step
# Epoch 00047: early stopping

# %%
test_predicted5 = model5.predict(x_test)
test_predicted5 = np.squeeze(test_predicted5)
mean_squared_error(y_test, test_predicted5)
# Out:
# 0.008161260810110694

# %%
plt.figure(figsize=(16, 6))
plt.title("Predictions using Stacked GRUs", size=15)
plt.plot(y_test, label="Actual")
plt.plot(test_predicted5, label="Predicted")
plt.xlim(0, 200)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %% [markdown]
# # Bidirectional Gated Recurrent Unit

# %%
from keras.models import Sequential
from keras.layers import Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10) 

model6 = Sequential()
model6.add(Bidirectional(GRU(200,
               activation="sigmoid",
               input_shape=(x_train.shape[1], x_train.shape[2]))))
model6.add(Dropout(0.2))
model6.add(Dense(1))
model6.compile(loss='mean_squared_error',
              optimizer= Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-06))
history6 = model6.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test), verbose=2, callbacks=es, shuffle=False)
# Out:
# Epoch 1/100
# 428/428 - 7s - loss: 0.0478 - val_loss: 0.0107 - 7s/epoch - 16ms/step
# Epoch 2/100
# 428/428 - 4s - loss: 0.0404 - val_loss: 0.0100 - 4s/epoch - 9ms/step
# Epoch 3/100
# 428/428 - 4s - loss: 0.0359 - val_loss: 0.0087 - 4s/epoch - 9ms/step
# Epoch 4/100
# 428/428 - 4s - loss: 0.0312 - val_loss: 0.0087 - 4s/epoch - 9ms/step
# Epoch 5/100
# 428/428 - 4s - loss: 0.0278 - val_loss: 0.0091 - 4s/epoch - 9ms/step
# Epoch 6/100
# 428/428 - 4s - loss: 0.0249 - val_loss: 0.0089 - 4s/epoch - 9ms/step
# Epoch 7/100
# 428/428 - 4s - loss: 0.0225 - val_loss: 0.0086 - 4s/epoch - 9ms/step
# Epoch 8/100
# 428/428 - 4s - loss: 0.0206 - val_loss: 0.0086 - 4s/epoch - 9ms/step
# Epoch 9/100
# 428/428 - 4s - loss: 0.0191 - val_loss: 0.0086 - 4s/epoch - 9ms/step
# Epoch 10/100
# 428/428 - 4s - loss: 0.0178 - val_loss: 0.0085 - 4s/epoch - 9ms/step
# Epoch 11/100
# 428/428 - 4s - loss: 0.0165 - val_loss: 0.0087 - 4s/epoch - 9ms/step
# Epoch 12/100
# 428/428 - 4s - loss: 0.0155 - val_loss: 0.0087 - 4s/epoch - 9ms/step
# Epoch 13/100
# 428/428 - 4s - loss: 0.0148 - val_loss: 0.0090 - 4s/epoch - 9ms/step
# Epoch 14/100
# 428/428 - 4s - loss: 0.0141 - val_loss: 0.0089 - 4s/epoch - 10ms/step
# Epoch 15/100
# 428/428 - 4s - loss: 0.0137 - val_loss: 0.0086 - 4s/epoch - 9ms/step
# Epoch 16/100
# 428/428 - 4s - loss: 0.0133 - val_loss: 0.0086 - 4s/epoch - 9ms/step
# Epoch 17/100
# 428/428 - 4s - loss: 0.0129 - val_loss: 0.0087 - 4s/epoch - 9ms/step
# Epoch 18/100
# 428/428 - 4s - loss: 0.0125 - val_loss: 0.0088 - 4s/epoch - 9ms/step
# Epoch 19/100
# 428/428 - 4s - loss: 0.0124 - val_loss: 0.0088 - 4s/epoch - 9ms/step
# Epoch 20/100
# 428/428 - 4s - loss: 0.0122 - val_loss: 0.0088 - 4s/epoch - 9ms/step
# Epoch 00020: early stopping

# %%
test_predicted6 = model6.predict(x_test)
test_predicted6 = np.squeeze(test_predicted6)
mean_squared_error(y_test, test_predicted6)
# Out:
# 0.00877884911155994

# %%
plt.figure(figsize=(16, 6))
plt.title("Prediction using Bidirectional GRU", size=15)
plt.plot(y_test, label = "Actual")
plt.plot(test_predicted6, label = "Predicted")
plt.xlim(0, 200)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %% [markdown]
# # CNN-LSTM

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(np.asarray(df["Global_active_power"]).reshape(-1, 1))

num_historical_entries = 30
data_input, data_output = [], []
for i in range(len(data)-num_historical_entries-1):
    data_input.append(np.asarray(data[i:(i+num_historical_entries)]))
    data_output.append(data[i + num_historical_entries])

x_train, y_train = np.asarray(data_input[:int(0.8*len(df))]), np.asarray(data_output[:int(0.8*len(df))])
x_test, y_test = np.asarray(data_input[int(0.8*len(df)):]), np.asarray(data_output[int(0.8*len(df)):])

x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

# %%
from keras.models import Sequential
from keras.layers import TimeDistributed, Conv1D, MaxPooling1D, Flatten, LSTM, Dense, Dropout, TimeDistributed
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10) 

model7 = Sequential()
model7.add(Conv1D(128, 1, input_shape=(x_train.shape[1], x_train.shape[2])))
model7.add(Dropout(0.2))
model7.add(LSTM(200,
               activation="sigmoid"))
model7.add(Dropout(0.2))
model7.add(Dense(1))
model7.compile(loss='mean_squared_error',
              optimizer= Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-06))
history7 = model7.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test), verbose=2, callbacks=es, shuffle=False)
# Out:
# Epoch 1/100
# 428/428 - 5s - loss: 0.0550 - val_loss: 0.0093 - 5s/epoch - 13ms/step
# Epoch 2/100
# 428/428 - 4s - loss: 0.0446 - val_loss: 0.0088 - 4s/epoch - 8ms/step
# Epoch 3/100
# 428/428 - 4s - loss: 0.0348 - val_loss: 0.0083 - 4s/epoch - 9ms/step
# Epoch 4/100
# 428/428 - 4s - loss: 0.0270 - val_loss: 0.0086 - 4s/epoch - 9ms/step
# Epoch 5/100
# 428/428 - 4s - loss: 0.0209 - val_loss: 0.0085 - 4s/epoch - 8ms/step
# Epoch 6/100
# 428/428 - 4s - loss: 0.0175 - val_loss: 0.0092 - 4s/epoch - 8ms/step
# Epoch 7/100
# 428/428 - 4s - loss: 0.0158 - val_loss: 0.0089 - 4s/epoch - 8ms/step
# Epoch 8/100
# 428/428 - 4s - loss: 0.0146 - val_loss: 0.0091 - 4s/epoch - 9ms/step
# Epoch 9/100
# 428/428 - 4s - loss: 0.0140 - val_loss: 0.0093 - 4s/epoch - 9ms/step
# Epoch 10/100
# 428/428 - 4s - loss: 0.0135 - val_loss: 0.0091 - 4s/epoch - 8ms/step
# Epoch 11/100
# 428/428 - 4s - loss: 0.0131 - val_loss: 0.0091 - 4s/epoch - 8ms/step
# Epoch 12/100
# 428/428 - 4s - loss: 0.0127 - val_loss: 0.0089 - 4s/epoch - 9ms/step
# Epoch 13/100
# 428/428 - 4s - loss: 0.0125 - val_loss: 0.0089 - 4s/epoch - 8ms/step
# Epoch 00013: early stopping

# %%
test_predicted7 = model.predict(x_test)
test_predicted7 = np.squeeze(test_predicted7)
mean_squared_error(y_test, test_predicted7)
# Out:
# 0.008712899867182499

# %%
plt.figure(figsize=(16, 6))
plt.title("Prediction using CNN-LSTM", size=15)
plt.plot(y_test, label = "Actual")
plt.plot(test_predicted7, label="Predicted")
plt.xlim(0, 200)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %%
plt.figure(figsize=(16, 6))
# plt.title("Prediction using LSTM", size=15)
plt.plot(y_test, linestyle = "--", label = "Actual")
plt.plot(test_predicted1, label="Simple LSTM")
plt.plot(test_predicted2, label="Stacked LSTM")
plt.plot(test_predicted3, label="Bidirectional LSTM")
plt.plot(test_predicted7, label="CNN LSTM")
plt.xlim(0, 100)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %%
plt.figure(figsize=(16, 6))
# plt.title("Prediction using GRU", size=15)
plt.plot(y_test, linestyle = "--", label = "Actual")
plt.plot(test_predicted4, label="Simple GRU")
plt.plot(test_predicted5, label="Stacked GRU")
plt.plot(test_predicted6, label="Bidirectional GRU")
plt.xlim(0, 100)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)

# %%
plt.figure(figsize=(16, 6))
# plt.title("Prediction using LSTM", size=15)
plt.plot(y_test, linestyle = "--", label = "Actual")
# plt.plot(test_predicted1, label="Simple LSTM")
# plt.plot(test_predicted2, label="Stacked LSTM")
# plt.plot(test_predicted3, label="Bidirectional LSTM")
plt.plot(test_predicted7, label="CNN LSTM")
plt.xlim(0, 100)
plt.ylim(0, 0.6)
plt.xlabel("Time Steps", size=12)
plt.ylabel("Normalized Power", size=12)
plt.legend()
plt.grid(True)
